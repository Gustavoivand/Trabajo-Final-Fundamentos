# %% [markdown]
# # PROCESO DE OPTIMIZACIÓN CON PYMOO

# %%
pip install pymoo
# Out:
# Collecting pymoo
#   Downloading pymoo-0.6.1.1.tar.gz (1.3 MB)
#      ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#       --------------------------------------- 0.0/1.3 MB 1.3 MB/s eta 0:00:01
#       --------------------------------------- 0.0/1.3 MB 1.3 MB/s eta 0:00:01
#      -- ------------------------------------- 0.1/1.3 MB 573.4 kB/s eta 0:00:03
#      --- ------------------------------------ 0.1/1.3 MB 726.2 kB/s eta 0:00:02
#      ------ --------------------------------- 0.2/1.3 MB 888.4 kB/s eta 0:00:02
#      ------- -------------------------------- 0.2/1.3 MB 1.0 MB/s eta 0:00:02
#      ------------ --------------------------- 0.4/1.3 MB 1.2 MB/s eta 0:00:01
#      --------------- ------------------------ 0.5/1.3 MB 1.5 MB/s eta 0:00:01
#      ------------------------ --------------- 0.8/1.3 MB 1.9 MB/s eta 0:00:01
#      -------------------------------- ------- 1.0/1.3 MB 2.2 MB/s eta 0:00:01
#      ---------------------------------------- 1.3/1.3 MB 2.5 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: numpy>=1.15 in c:\users\gusta\appdata\local\programs\python\python312\lib\site-packages (from pymoo) (1.26.4)
# Requirement already satisfied: scipy>=1.1 in c:\users\gusta\appdata\local\programs\python\python312\lib\site-packages (from pymoo) (1.12.0)
# Collecting matplotlib>=3 (from pymoo)
#   Downloading matplotlib-3.9.0-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Collecting autograd>=1.4 (from pymoo)
#   Using cached autograd-1.6.2-py3-none-any.whl.metadata (706 bytes)
# Collecting cma==3.2.2 (from pymoo)
#   Using cached cma-3.2.2-py2.py3-none-any.whl.metadata (8.0 kB)
# Collecting alive-progress (from pymoo)
#   Using cached alive_progress-3.1.5-py3-none-any.whl.metadata (68 kB)
# Collecting dill (from pymoo)
#   Using cached dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Collecting Deprecated (from pymoo)
#   Using cached Deprecated-1.2.14-py2.py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: future>=0.15.2 in c:\users\gusta\appdata\local\programs\python\python312\lib\site-packages (from autograd>=1.4->pymoo) (1.0.0)
# Collecting contourpy>=1.0.1 (from matplotlib>=3->pymoo)
#   Downloading contourpy-1.2.1-cp312-cp312-win_amd64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib>=3->pymoo)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib>=3->pymoo)
#   Downloading fonttools-4.53.0-cp312-cp312-win_amd64.whl.metadata (165 kB)
#      ---------------------------------------- 0.0/165.5 kB ? eta -:--:--
#      -------------------------------------- 165.5/165.5 kB 9.7 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib>=3->pymoo)
#   Downloading kiwisolver-1.4.5-cp312-cp312-win_amd64.whl.metadata (6.5 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\gusta\appdata\roaming\python\python312\site-packages (from matplotlib>=3->pymoo) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\gusta\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3->pymoo) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\gusta\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3->pymoo) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\gusta\appdata\roaming\python\python312\site-packages (from matplotlib>=3->pymoo) (2.8.2)
# Collecting about-time==4.2.1 (from alive-progress->pymoo)
#   Using cached about_time-4.2.1-py3-none-any.whl.metadata (13 kB)
# Collecting grapheme==0.6.0 (from alive-progress->pymoo)
#   Using cached grapheme-0.6.0.tar.gz (207 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting wrapt<2,>=1.10 (from Deprecated->pymoo)
#   Downloading wrapt-1.16.0-cp312-cp312-win_amd64.whl.metadata (6.8 kB)
# Requirement already satisfied: six>=1.5 in c:\users\gusta\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib>=3->pymoo) (1.16.0)
# Using cached cma-3.2.2-py2.py3-none-any.whl (249 kB)
# Using cached autograd-1.6.2-py3-none-any.whl (49 kB)
# Downloading matplotlib-3.9.0-cp312-cp312-win_amd64.whl (8.0 MB)
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.0 MB 15.2 MB/s eta 0:00:01
#    ----- ---------------------------------- 1.0/8.0 MB 12.9 MB/s eta 0:00:01
#    ------- -------------------------------- 1.6/8.0 MB 12.5 MB/s eta 0:00:01
#    ---------- ----------------------------- 2.1/8.0 MB 12.3 MB/s eta 0:00:01
#    ------------- -------------------------- 2.7/8.0 MB 12.1 MB/s eta 0:00:01
#    ---------------- ----------------------- 3.2/8.0 MB 12.1 MB/s eta 0:00:01
#    ------------------- -------------------- 3.8/8.0 MB 12.1 MB/s eta 0:00:01
#    --------------------- ------------------ 4.4/8.0 MB 12.1 MB/s eta 0:00:01
#    ------------------------ --------------- 4.9/8.0 MB 12.0 MB/s eta 0:00:01
#    --------------------------- ------------ 5.4/8.0 MB 12.0 MB/s eta 0:00:01
#    ------------------------------ --------- 6.0/8.0 MB 12.0 MB/s eta 0:00:01
#    ------------------------------ --------- 6.1/8.0 MB 12.1 MB/s eta 0:00:01
#    -------------------------------- ------- 6.4/8.0 MB 10.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 7.0/8.0 MB 10.8 MB/s eta 0:00:01
#    ------------------------------------- -- 7.5/8.0 MB 10.9 MB/s eta 0:00:01
#    ---------------------------------------  8.0/8.0 MB 10.8 MB/s eta 0:00:01
#    ---------------------------------------- 8.0/8.0 MB 10.6 MB/s eta 0:00:00
# Using cached alive_progress-3.1.5-py3-none-any.whl (75 kB)
# Using cached about_time-4.2.1-py3-none-any.whl (13 kB)
# Using cached Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Using cached dill-0.3.8-py3-none-any.whl (116 kB)
# Downloading contourpy-1.2.1-cp312-cp312-win_amd64.whl (189 kB)
#    ---------------------------------------- 0.0/189.9 kB ? eta -:--:--
#    --------------------------------------- 189.9/189.9 kB 12.0 MB/s eta 0:00:00
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.53.0-cp312-cp312-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.2 MB 14.4 MB/s eta 0:00:01
#    ------------------ --------------------- 1.0/2.2 MB 12.8 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.6/2.2 MB 12.5 MB/s eta 0:00:01
#    ---------------------------------------  2.1/2.2 MB 12.4 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 11.6 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.5-cp312-cp312-win_amd64.whl (56 kB)
#    ---------------------------------------- 0.0/56.0 kB ? eta -:--:--
#    ---------------------------------------- 56.0/56.0 kB 3.1 MB/s eta 0:00:00
# Downloading wrapt-1.16.0-cp312-cp312-win_amd64.whl (37 kB)
# Building wheels for collected packages: pymoo, grapheme
#   Building wheel for pymoo (pyproject.toml): started
#   Building wheel for pymoo (pyproject.toml): finished with status 'done'
#   Created wheel for pymoo: filename=pymoo-0.6.1.1-py3-none-any.whl size=329981 sha256=94563550068a3036af612bef1d850d049f70eeb62f6ff94153745237bb9cdc36
#   Stored in directory: c:\users\gusta\appdata\local\pip\cache\wheels\f3\c7\53\97f8cb932ee19ed10ab46dbb507ecfae9ea0ba0c16130341f6
#   Building wheel for grapheme (pyproject.toml): started
#   Building wheel for grapheme (pyproject.toml): finished with status 'done'
#   Created wheel for grapheme: filename=grapheme-0.6.0-py3-none-any.whl size=210116 sha256=a95deb38a90e0e57394ce7e19ec23df03597345861dade65cc4badfde44aa37e
#   Stored in directory: c:\users\gusta\appdata\local\pip\cache\wheels\5b\aa\3b\d94434910f5e19ac7f8aa6523d74a46fe06bfcbc7e4b26caf6
# Successfully built pymoo grapheme
# Installing collected packages: grapheme, wrapt, kiwisolver, fonttools, dill, cycler, contourpy, cma, autograd, about-time, matplotlib, Deprecated, alive-progress, pymoo
# Successfully installed Deprecated-1.2.14 about-time-4.2.1 alive-progress-3.1.5 autograd-1.6.2 cma-3.2.2 contourpy-1.2.1 cycler-0.12.1 dill-0.3.8 fonttools-4.53.0 grapheme-0.6.0 kiwisolver-1.4.5 matplotlib-3.9.0 pymoo-0.6.1.1 wrapt-1.16.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
df = pd.read_csv("dataset.csv")

# %%
df.head
# Out:
# <bound method NDFrame.head of          Drift   pc1   pc2   pc3   pc4  pv1  pv2  pv3  pv4  MasaPropia  \
# 0     0.004221  0.25  0.25  0.25  0.25  0.2  0.2  0.2  0.4      6300.0
# 1     0.004124  0.25  0.25  0.25  0.25  0.2  0.2  0.2  0.6      7080.0
# 2     0.005613  0.25  0.25  0.25  0.25  0.2  0.2  0.4  0.2      6300.0
# 3     0.004334  0.25  0.25  0.25  0.25  0.2  0.2  0.4  0.4      7080.0
# 4     0.004199  0.25  0.25  0.25  0.25  0.2  0.2  0.4  0.6      7860.0
# ...        ...   ...   ...   ...   ...  ...  ...  ...  ...         ...
# 6555  0.000478  0.65  0.65  0.65  0.65  0.6  0.6  0.4  0.4     14040.0
# 6556  0.000403  0.65  0.65  0.65  0.65  0.6  0.6  0.4  0.6     14820.0
# 6557  0.000574  0.65  0.65  0.65  0.65  0.6  0.6  0.6  0.2     14040.0
# 6558  0.000492  0.65  0.65  0.65  0.65  0.6  0.6  0.6  0.4     14820.0
# 6559  0.000414  0.65  0.65  0.65  0.65  0.6  0.6  0.6  0.6     15600.0
#
#                 Px
# 0     57699.704555
# 1     60071.550118
# 2     57699.704555
# 3     60071.550118
# 4     62443.395680
# ...            ...
# 6555  81235.710524
# 6556  83607.556086
# 6557  81235.710524
# 6558  83607.556086
# 6559  85979.401649
#
# [6560 rows x 11 columns]>

# %%
import pickle

# %%
# Loading Existing Models

Drift_model_path = "Drift.pkl"
MasaPropia_model_path = "MasaPropia.pkl"

with open(Drift_model_path, 'rb') as f:
    Drift_model = pickle.load(f)

with open(MasaPropia_model_path , 'rb') as f:
    MasaPropia_model = pickle.load(f)

# %%
X = df.drop(columns =  ["Drift" , "MasaPropia","Px"])

# %%
Drift_model
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler())]),
#                                                   Index(['pc1', 'pc2', 'pc3', 'pc4', 'pv1', 'pv2', 'pv3', 'pv4'], dtype='object')),
#                                                  ('cat',
#                                                   Pipeline(steps=[('one_hot_encoder',
#                                                                    OneHotEncoder())]),
#                                                   Index([], dtype='object'))])),
#                 ('regressor', RandomForestRegressor())])

# %%
Drift_model.predict(X)
# Out:
# array([0.00425457, 0.00415684, 0.00570744, ..., 0.00057289, 0.00048941,
#        0.00040873])

# %%
MasaPropia_model.predict(X)
# Out:
# array([ 6471. ,  7282.2,  6481.2, ..., 13827. , 14676. , 15412.2])

# %%
from pymoo.core.variable import Choice, Real, Integer

# %%
X.columns
# Out:
# Index(['pc1', 'pc2', 'pc3', 'pc4', 'pv1', 'pv2', 'pv3', 'pv4'], dtype='object')

# %%
mixed_variables = {
    "pc1" : Real(bounds=(df['pc1'].min(),df['pc1'].max())),
    "pc2" : Real(bounds=(df['pc2'].min(),df['pc2'].max())),
    "pc3" : Real(bounds=(df['pc3'].min(),df['pc3'].max())),
    "pc4" : Real(bounds=(df['pc4'].min(),df['pc4'].max())),
    "pv1" : Real(bounds=(df['pv1'].min(),df['pv1'].max())),
    "pv2" : Real(bounds=(df['pv2'].min(),df['pv2'].max())),
    "pv3" : Real(bounds=(df['pv3'].min(),df['pv3'].max())),
    "pv4" : Real(bounds=(df['pv4'].min(),df['pv4'].max())),
}

# %%
mixed_variables
# Out:
# {'pc1': <pymoo.core.variable.Real at 0x269df5f3680>,
#  'pc2': <pymoo.core.variable.Real at 0x26994445f10>,
#  'pc3': <pymoo.core.variable.Real at 0x269ff84b530>,
#  'pc4': <pymoo.core.variable.Real at 0x269df5f39e0>,
#  'pv1': <pymoo.core.variable.Real at 0x269944450d0>,
#  'pv2': <pymoo.core.variable.Real at 0x26994445070>,
#  'pv3': <pymoo.core.variable.Real at 0x26994444b60>,
#  'pv4': <pymoo.core.variable.Real at 0x26994444a40>}

# %%
import numpy as np

# %%
from pymoo.core.problem import (
                        Problem,           # Vectorized - since most MO algorithms work with populations, this class evaluates a set of solutons at once
                        ElementwiseProblem # Inherits from the Problem Class, works with a single solution at a time
                               )
from pymoo.problems.functional import FunctionalProblem  # Inherits from the ElementwiseProblem class , works with functions for each objective and constraint

# %%
class DriftMasa(Problem):

    def __init__(self, **kwargs):
        super().__init__(vars = mixed_variables, n_obj = 1,
                         n_ieq_constr = 1 , n_eq_constr = 0 ,
                         **kwargs)

    def _evaluate(self, x, out, *args, **kwargs):

        # Type conversion for Prediction and Constraint
        temp_df = pd.DataFrame(list(x))


        obj1 = 1*MasaPropia_model.predict(temp_df) # Minimase

        #equality_constraint = temp_df[["Coke %", "Minerals %"]].sum(axis = 1) - 100 #=0
        inequality_constraint = Drift_model.predict(temp_df) - 0.005#<0

        out["F"] = np.column_stack([obj1 ])
        out["G"] = np.column_stack([inequality_constraint])
        #out["H"] = np.column_stack([equality_constraint])

# %%
from pymoo.algorithms.moo.nsga2 import NSGA2
algorithm = NSGA2(pop_size = 200)
# Out:
# Compiled modules for significant speedup can not be used!
# https://pymoo.org/installation.html#installation
#
# To disable this warning:
# from pymoo.config import Config
# Config.warnings['not_compiled'] = False

# %%
from pymoo.algorithms.soo.nonconvex.de import DE # Differential Evolution
from pymoo.algorithms.soo.nonconvex.ga import GA # Genetic Algorithm
from pymoo.algorithms.soo.nonconvex.nelder import NelderMead
from pymoo.optimize import minimize

# %%
from pymoo.core.mixed import MixedVariableMating, MixedVariableSampling, MixedVariableDuplicateElimination

problem = DriftMasa()

algorithm = NSGA2(pop_size = 100,
                  sampling = MixedVariableSampling(),
                  mating=MixedVariableMating(eliminate_duplicates=MixedVariableDuplicateElimination()),
                  eliminate_duplicates = False)

res = minimize(problem,
               algorithm,
               ('n_gen', 100),
               verbose = False,
              seed = 42)

# %%
result = pd.DataFrame(list(res.X))
result['MasaPropia'] = 1*res.F
result['Drift'] = Drift_model.predict(result)

# %%
import matplotlib.pyplot as plt
plt.scatter(result['Drift'] , result['MasaPropia'], s = 30, color = 'blue');
plt.scatter(df['Drift'] , df['MasaPropia'], s = 30, alpha = 0.2, facecolors='none', edgecolors='#A6A6A6');
plt.xlabel("Drift")
plt.ylabel("Masa Propia (Kg)");

# %%
result.head(100)
# Out:
#          pc1       pc2       pc3       pc4       pv1       pv2       pv3  \
# 0   0.256309  0.428836  0.255439  0.282968  0.201013  0.277832  0.263991
# 1   0.325858  0.405370  0.284896  0.313132  0.203721  0.203979  0.256096
# 2   0.254720  0.405555  0.307869  0.271891  0.200455  0.202053  0.273358
# 3   0.272374  0.443930  0.284080  0.295202  0.201099  0.238335  0.221663
# 4   0.257463  0.413880  0.282823  0.318001  0.244668  0.216051  0.261840
# ..       ...       ...       ...       ...       ...       ...       ...
# 95  0.272011  0.436300  0.300133  0.277463  0.200574  0.213791  0.246263
# 96  0.296513  0.403171  0.297544  0.257582  0.234187  0.245598  0.268721
# 97  0.253573  0.389709  0.271793  0.284681  0.223265  0.255935  0.241128
# 98  0.339117  0.415289  0.268868  0.284248  0.204984  0.223723  0.237080
# 99  0.250552  0.377718  0.332769  0.289183  0.202332  0.259341  0.289510
#
#          pv4  MasaPropia     Drift
# 0   0.284658      6127.2  0.003697
# 1   0.201810      6127.2  0.003697
# 2   0.244864      6127.2  0.003697
# 3   0.212948      6127.2  0.003697
# 4   0.264555      6127.2  0.003697
# ..       ...         ...       ...
# 95  0.226522      6127.2  0.003697
# 96  0.264494      6127.2  0.003697
# 97  0.287131      6127.2  0.003697
# 98  0.265324      6127.2  0.003697
# 99  0.269653      6127.2  0.003697
#
# [100 rows x 10 columns]
